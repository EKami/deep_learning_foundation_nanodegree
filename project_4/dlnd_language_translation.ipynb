# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source_text_list = source_text.split('\n')
    target_text_list = [sentence + ' <EOS>' for sentence in target_text.split('\n')]
    
    source_ret = [None] * len(source_text_list)
    target_ret = [None] * len(target_text_list)
    for i, sentence in enumerate(source_text_list):
        source_ret[i] = [source_vocab_to_int[word] for word in sentence.split(' ') if word in source_vocab_to_int]
    for i, sentence in enumerate(target_text_list):
        target_ret[i] = [target_vocab_to_int[word] for word in sentence.split(' ') if word in target_vocab_to_int]
    return source_ret, target_ret

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    inputs = tf.placeholder(tf.int32, [None, None], "input")
    targets = tf.placeholder(tf.int32, [None, None], "targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    
    return inputs, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    
    if debug_decoding:
        demonstration_outputs = np.reshape(range(target_data.shape[0] * target_data.shape[1]), (target_data.shape[0], target_data.shape[1]))
        sess = tf.InteractiveSession()
        print("Targets")
        print(demonstration_outputs[:2])
        print("\n")
        print("Processed Decoding Input")
        print(sess.run(dec_input, {target_data: demonstration_outputs})[:2])
        sess.close()
        
    return dec_input

debug_decoding = True
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
debug_decoding = False
# Out:
# Targets
# [[0 1 2]
#  [3 4 5]]
#
#
# Processed Decoding Input
# [[3 0 1]
#  [3 3 4]]
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """

    # Encoder
    enc_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    dropout = tf.contrib.rnn.DropoutWrapper(enc_cell, keep_prob)
    _, enc_state = tf.nn.dynamic_rnn(enc_cell, rnn_inputs, dtype=tf.float32)
    return enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # Training Decoder
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    dropout = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dropout, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    
    # Apply output function
    train_logits = output_fn(train_pred)
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # Inference Decoder
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size)
    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    
    # Not sure where to apply dropout here...
    return inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    
    with tf.variable_scope("decoding") as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        train_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)
    
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        inf_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], 
                                          sequence_length - 1, vocab_size, decoding_scope, output_fn, keep_prob)
    return (train_logits, inf_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # Encoder embedding
    rnn_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    enc_state = encoding_layer(rnn_input, rnn_size, num_layers, keep_prob)
    
    dec_input_target = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    
    # Decoder Embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input_target)
    
    training_logits, inference_logits = decoding_layer(dec_embed_input, dec_embeddings, enc_state, target_vocab_size, sequence_length, 
                         rnn_size, num_layers, target_vocab_to_int, keep_prob)
    
    return (training_logits, inference_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 20
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            
            if batch_i % 100 == 0:
                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/1077 - Train Accuracy:  0.188, Validation Accuracy:  0.225, Loss:  5.879
# Epoch   0 Batch  100/1077 - Train Accuracy:  0.262, Validation Accuracy:  0.336, Loss:  3.357
# Epoch   0 Batch  200/1077 - Train Accuracy:  0.351, Validation Accuracy:  0.402, Loss:  2.932
# Epoch   0 Batch  300/1077 - Train Accuracy:  0.336, Validation Accuracy:  0.424, Loss:  2.792
# Epoch   0 Batch  400/1077 - Train Accuracy:  0.397, Validation Accuracy:  0.459, Loss:  2.518
# Epoch   0 Batch  500/1077 - Train Accuracy:  0.442, Validation Accuracy:  0.480, Loss:  2.330
# Epoch   0 Batch  600/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.497, Loss:  2.086
# Epoch   0 Batch  700/1077 - Train Accuracy:  0.452, Validation Accuracy:  0.503, Loss:  2.014
# Epoch   0 Batch  800/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.501, Loss:  1.950
# Epoch   0 Batch  900/1077 - Train Accuracy:  0.435, Validation Accuracy:  0.495, Loss:  1.736
# Epoch   0 Batch 1000/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.472, Loss:  1.444
# Epoch   1 Batch    0/1077 - Train Accuracy:  0.488, Validation Accuracy:  0.497, Loss:  1.362
# Epoch   1 Batch  100/1077 - Train Accuracy:  0.447, Validation Accuracy:  0.475, Loss:  1.323
# Epoch   1 Batch  200/1077 - Train Accuracy:  0.423, Validation Accuracy:  0.461, Loss:  1.247
# Epoch   1 Batch  300/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.438, Loss:  1.237
# Epoch   1 Batch  400/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.459, Loss:  1.150
# Epoch   1 Batch  500/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.496, Loss:  1.068
# Epoch   1 Batch  600/1077 - Train Accuracy:  0.474, Validation Accuracy:  0.488, Loss:  0.977
# Epoch   1 Batch  700/1077 - Train Accuracy:  0.461, Validation Accuracy:  0.477, Loss:  0.948
# Epoch   1 Batch  800/1077 - Train Accuracy:  0.443, Validation Accuracy:  0.456, Loss:  0.962
# Epoch   1 Batch  900/1077 - Train Accuracy:  0.434, Validation Accuracy:  0.473, Loss:  0.936
# Epoch   1 Batch 1000/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.473, Loss:  0.831
# Epoch   2 Batch    0/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.519, Loss:  0.821
# Epoch   2 Batch  100/1077 - Train Accuracy:  0.510, Validation Accuracy:  0.542, Loss:  0.835
# Epoch   2 Batch  200/1077 - Train Accuracy:  0.525, Validation Accuracy:  0.567, Loss:  0.822
# Epoch   2 Batch  300/1077 - Train Accuracy:  0.512, Validation Accuracy:  0.574, Loss:  0.806
# Epoch   2 Batch  400/1077 - Train Accuracy:  0.583, Validation Accuracy:  0.594, Loss:  0.777
# Epoch   2 Batch  500/1077 - Train Accuracy:  0.557, Validation Accuracy:  0.604, Loss:  0.750
# Epoch   2 Batch  600/1077 - Train Accuracy:  0.605, Validation Accuracy:  0.611, Loss:  0.689
# Epoch   2 Batch  700/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.586, Loss:  0.687
# Epoch   2 Batch  800/1077 - Train Accuracy:  0.532, Validation Accuracy:  0.610, Loss:  0.687
# Epoch   2 Batch  900/1077 - Train Accuracy:  0.581, Validation Accuracy:  0.589, Loss:  0.692
# Epoch   2 Batch 1000/1077 - Train Accuracy:  0.653, Validation Accuracy:  0.631, Loss:  0.606
# Epoch   3 Batch    0/1077 - Train Accuracy:  0.612, Validation Accuracy:  0.625, Loss:  0.605
# Epoch   3 Batch  100/1077 - Train Accuracy:  0.617, Validation Accuracy:  0.643, Loss:  0.628
# Epoch   3 Batch  200/1077 - Train Accuracy:  0.598, Validation Accuracy:  0.643, Loss:  0.630
# Epoch   3 Batch  300/1077 - Train Accuracy:  0.608, Validation Accuracy:  0.644, Loss:  0.617
# Epoch   3 Batch  400/1077 - Train Accuracy:  0.624, Validation Accuracy:  0.650, Loss:  0.598
# Epoch   3 Batch  500/1077 - Train Accuracy:  0.608, Validation Accuracy:  0.653, Loss:  0.582
# Epoch   3 Batch  600/1077 - Train Accuracy:  0.645, Validation Accuracy:  0.659, Loss:  0.543
# Epoch   3 Batch  700/1077 - Train Accuracy:  0.615, Validation Accuracy:  0.665, Loss:  0.549
# Epoch   3 Batch  800/1077 - Train Accuracy:  0.606, Validation Accuracy:  0.657, Loss:  0.555
# Epoch   3 Batch  900/1077 - Train Accuracy:  0.636, Validation Accuracy:  0.662, Loss:  0.561
# Epoch   3 Batch 1000/1077 - Train Accuracy:  0.682, Validation Accuracy:  0.668, Loss:  0.497
# Epoch   4 Batch    0/1077 - Train Accuracy:  0.644, Validation Accuracy:  0.671, Loss:  0.497
# Epoch   4 Batch  100/1077 - Train Accuracy:  0.660, Validation Accuracy:  0.672, Loss:  0.530
# Epoch   4 Batch  200/1077 - Train Accuracy:  0.646, Validation Accuracy:  0.656, Loss:  0.520
# Epoch   4 Batch  300/1077 - Train Accuracy:  0.650, Validation Accuracy:  0.661, Loss:  0.511
# Epoch   4 Batch  400/1077 - Train Accuracy:  0.639, Validation Accuracy:  0.673, Loss:  0.508
# Epoch   4 Batch  500/1077 - Train Accuracy:  0.661, Validation Accuracy:  0.666, Loss:  0.486
# Epoch   4 Batch  600/1077 - Train Accuracy:  0.663, Validation Accuracy:  0.683, Loss:  0.451
# Epoch   4 Batch  700/1077 - Train Accuracy:  0.623, Validation Accuracy:  0.665, Loss:  0.460
# Epoch   4 Batch  800/1077 - Train Accuracy:  0.650, Validation Accuracy:  0.659, Loss:  0.457
# Epoch   4 Batch  900/1077 - Train Accuracy:  0.689, Validation Accuracy:  0.673, Loss:  0.465
# Epoch   4 Batch 1000/1077 - Train Accuracy:  0.709, Validation Accuracy:  0.673, Loss:  0.416
# Epoch   5 Batch    0/1077 - Train Accuracy:  0.650, Validation Accuracy:  0.672, Loss:  0.414
# Epoch   5 Batch  100/1077 - Train Accuracy:  0.671, Validation Accuracy:  0.664, Loss:  0.436
# Epoch   5 Batch  200/1077 - Train Accuracy:  0.680, Validation Accuracy:  0.656, Loss:  0.425
# Epoch   5 Batch  300/1077 - Train Accuracy:  0.693, Validation Accuracy:  0.665, Loss:  0.410
# Epoch   5 Batch  400/1077 - Train Accuracy:  0.697, Validation Accuracy:  0.684, Loss:  0.418
# Epoch   5 Batch  500/1077 - Train Accuracy:  0.716, Validation Accuracy:  0.666, Loss:  0.393
# Epoch   5 Batch  600/1077 - Train Accuracy:  0.691, Validation Accuracy:  0.673, Loss:  0.361
# Epoch   5 Batch  700/1077 - Train Accuracy:  0.689, Validation Accuracy:  0.668, Loss:  0.370
# Epoch   5 Batch  800/1077 - Train Accuracy:  0.669, Validation Accuracy:  0.683, Loss:  0.368
# Epoch   5 Batch  900/1077 - Train Accuracy:  0.720, Validation Accuracy:  0.684, Loss:  0.369
# Epoch   5 Batch 1000/1077 - Train Accuracy:  0.735, Validation Accuracy:  0.694, Loss:  0.327
# Epoch   6 Batch    0/1077 - Train Accuracy:  0.699, Validation Accuracy:  0.685, Loss:  0.320
# Epoch   6 Batch  100/1077 - Train Accuracy:  0.701, Validation Accuracy:  0.702, Loss:  0.343
# Epoch   6 Batch  200/1077 - Train Accuracy:  0.695, Validation Accuracy:  0.704, Loss:  0.338
# Epoch   6 Batch  300/1077 - Train Accuracy:  0.734, Validation Accuracy:  0.710, Loss:  0.324
# Epoch   6 Batch  400/1077 - Train Accuracy:  0.745, Validation Accuracy:  0.713, Loss:  0.335
# Epoch   6 Batch  500/1077 - Train Accuracy:  0.746, Validation Accuracy:  0.720, Loss:  0.305
# Epoch   6 Batch  600/1077 - Train Accuracy:  0.736, Validation Accuracy:  0.723, Loss:  0.288
# Epoch   6 Batch  700/1077 - Train Accuracy:  0.737, Validation Accuracy:  0.718, Loss:  0.280
# Epoch   6 Batch  800/1077 - Train Accuracy:  0.740, Validation Accuracy:  0.721, Loss:  0.294
# Epoch   6 Batch  900/1077 - Train Accuracy:  0.755, Validation Accuracy:  0.717, Loss:  0.301
# Epoch   6 Batch 1000/1077 - Train Accuracy:  0.760, Validation Accuracy:  0.739, Loss:  0.263
# Epoch   7 Batch    0/1077 - Train Accuracy:  0.741, Validation Accuracy:  0.737, Loss:  0.252
# Epoch   7 Batch  100/1077 - Train Accuracy:  0.748, Validation Accuracy:  0.743, Loss:  0.280
# Epoch   7 Batch  200/1077 - Train Accuracy:  0.711, Validation Accuracy:  0.720, Loss:  0.268
# Epoch   7 Batch  300/1077 - Train Accuracy:  0.769, Validation Accuracy:  0.736, Loss:  0.251
# Epoch   7 Batch  400/1077 - Train Accuracy:  0.786, Validation Accuracy:  0.756, Loss:  0.266
# Epoch   7 Batch  500/1077 - Train Accuracy:  0.797, Validation Accuracy:  0.751, Loss:  0.236
# Epoch   7 Batch  600/1077 - Train Accuracy:  0.777, Validation Accuracy:  0.761, Loss:  0.232
# Epoch   7 Batch  700/1077 - Train Accuracy:  0.763, Validation Accuracy:  0.749, Loss:  0.219
# Epoch   7 Batch  800/1077 - Train Accuracy:  0.787, Validation Accuracy:  0.765, Loss:  0.227
# Epoch   7 Batch  900/1077 - Train Accuracy:  0.785, Validation Accuracy:  0.732, Loss:  0.234
# Epoch   7 Batch 1000/1077 - Train Accuracy:  0.804, Validation Accuracy:  0.776, Loss:  0.205
# Epoch   8 Batch    0/1077 - Train Accuracy:  0.785, Validation Accuracy:  0.771, Loss:  0.193
# Epoch   8 Batch  100/1077 - Train Accuracy:  0.792, Validation Accuracy:  0.779, Loss:  0.213
# Epoch   8 Batch  200/1077 - Train Accuracy:  0.764, Validation Accuracy:  0.765, Loss:  0.209
# Epoch   8 Batch  300/1077 - Train Accuracy:  0.780, Validation Accuracy:  0.766, Loss:  0.194
# Epoch   8 Batch  400/1077 - Train Accuracy:  0.847, Validation Accuracy:  0.782, Loss:  0.211
# Epoch   8 Batch  500/1077 - Train Accuracy:  0.847, Validation Accuracy:  0.770, Loss:  0.186
# Epoch   8 Batch  600/1077 - Train Accuracy:  0.824, Validation Accuracy:  0.757, Loss:  0.181
# Epoch   8 Batch  700/1077 - Train Accuracy:  0.848, Validation Accuracy:  0.773, Loss:  0.167
# Epoch   8 Batch  800/1077 - Train Accuracy:  0.814, Validation Accuracy:  0.791, Loss:  0.182
# Epoch   8 Batch  900/1077 - Train Accuracy:  0.847, Validation Accuracy:  0.779, Loss:  0.182
# Epoch   8 Batch 1000/1077 - Train Accuracy:  0.853, Validation Accuracy:  0.806, Loss:  0.164
# Epoch   9 Batch    0/1077 - Train Accuracy:  0.819, Validation Accuracy:  0.799, Loss:  0.158
# Epoch   9 Batch  100/1077 - Train Accuracy:  0.836, Validation Accuracy:  0.840, Loss:  0.165
# Epoch   9 Batch  200/1077 - Train Accuracy:  0.802, Validation Accuracy:  0.810, Loss:  0.170
# Epoch   9 Batch  300/1077 - Train Accuracy:  0.848, Validation Accuracy:  0.798, Loss:  0.151
# Epoch   9 Batch  400/1077 - Train Accuracy:  0.870, Validation Accuracy:  0.833, Loss:  0.168
# Epoch   9 Batch  500/1077 - Train Accuracy:  0.883, Validation Accuracy:  0.827, Loss:  0.150
# Epoch   9 Batch  600/1077 - Train Accuracy:  0.842, Validation Accuracy:  0.827, Loss:  0.150
# Epoch   9 Batch  700/1077 - Train Accuracy:  0.863, Validation Accuracy:  0.837, Loss:  0.133
# Epoch   9 Batch  800/1077 - Train Accuracy:  0.845, Validation Accuracy:  0.834, Loss:  0.144
# Epoch   9 Batch  900/1077 - Train Accuracy:  0.880, Validation Accuracy:  0.823, Loss:  0.152
# Epoch   9 Batch 1000/1077 - Train Accuracy:  0.860, Validation Accuracy:  0.862, Loss:  0.124
# Epoch  10 Batch    0/1077 - Train Accuracy:  0.863, Validation Accuracy:  0.858, Loss:  0.119
# Epoch  10 Batch  100/1077 - Train Accuracy:  0.874, Validation Accuracy:  0.844, Loss:  0.125
# Epoch  10 Batch  200/1077 - Train Accuracy:  0.821, Validation Accuracy:  0.857, Loss:  0.131
# Epoch  10 Batch  300/1077 - Train Accuracy:  0.877, Validation Accuracy:  0.835, Loss:  0.118
# Epoch  10 Batch  400/1077 - Train Accuracy:  0.878, Validation Accuracy:  0.837, Loss:  0.129
# Epoch  10 Batch  500/1077 - Train Accuracy:  0.891, Validation Accuracy:  0.846, Loss:  0.115
# Epoch  10 Batch  600/1077 - Train Accuracy:  0.864, Validation Accuracy:  0.866, Loss:  0.118
# Epoch  10 Batch  700/1077 - Train Accuracy:  0.895, Validation Accuracy:  0.850, Loss:  0.099
# Epoch  10 Batch  800/1077 - Train Accuracy:  0.850, Validation Accuracy:  0.868, Loss:  0.112
# Epoch  10 Batch  900/1077 - Train Accuracy:  0.905, Validation Accuracy:  0.858, Loss:  0.122
# Epoch  10 Batch 1000/1077 - Train Accuracy:  0.886, Validation Accuracy:  0.873, Loss:  0.096
# Epoch  11 Batch    0/1077 - Train Accuracy:  0.879, Validation Accuracy:  0.871, Loss:  0.095
# Epoch  11 Batch  100/1077 - Train Accuracy:  0.886, Validation Accuracy:  0.861, Loss:  0.100
# Epoch  11 Batch  200/1077 - Train Accuracy:  0.825, Validation Accuracy:  0.884, Loss:  0.105
# Epoch  11 Batch  300/1077 - Train Accuracy:  0.917, Validation Accuracy:  0.866, Loss:  0.089
# Epoch  11 Batch  400/1077 - Train Accuracy:  0.885, Validation Accuracy:  0.852, Loss:  0.107
# Epoch  11 Batch  500/1077 - Train Accuracy:  0.908, Validation Accuracy:  0.865, Loss:  0.092
# Epoch  11 Batch  600/1077 - Train Accuracy:  0.876, Validation Accuracy:  0.871, Loss:  0.096
# Epoch  11 Batch  700/1077 - Train Accuracy:  0.890, Validation Accuracy:  0.865, Loss:  0.080
# Epoch  11 Batch  800/1077 - Train Accuracy:  0.864, Validation Accuracy:  0.880, Loss:  0.091
# Epoch  11 Batch  900/1077 - Train Accuracy:  0.912, Validation Accuracy:  0.879, Loss:  0.090
# Epoch  11 Batch 1000/1077 - Train Accuracy:  0.890, Validation Accuracy:  0.878, Loss:  0.080
# Epoch  12 Batch    0/1077 - Train Accuracy:  0.896, Validation Accuracy:  0.887, Loss:  0.078
# Epoch  12 Batch  100/1077 - Train Accuracy:  0.895, Validation Accuracy:  0.880, Loss:  0.082
# Epoch  12 Batch  200/1077 - Train Accuracy:  0.846, Validation Accuracy:  0.894, Loss:  0.082
# Epoch  12 Batch  300/1077 - Train Accuracy:  0.929, Validation Accuracy:  0.862, Loss:  0.072
# Epoch  12 Batch  400/1077 - Train Accuracy:  0.874, Validation Accuracy:  0.877, Loss:  0.080
# Epoch  12 Batch  500/1077 - Train Accuracy:  0.920, Validation Accuracy:  0.874, Loss:  0.070
# Epoch  12 Batch  600/1077 - Train Accuracy:  0.891, Validation Accuracy:  0.870, Loss:  0.081
# Epoch  12 Batch  700/1077 - Train Accuracy:  0.917, Validation Accuracy:  0.871, Loss:  0.066
# Epoch  12 Batch  800/1077 - Train Accuracy:  0.868, Validation Accuracy:  0.887, Loss:  0.077
# Epoch  12 Batch  900/1077 - Train Accuracy:  0.913, Validation Accuracy:  0.885, Loss:  0.070
# Epoch  12 Batch 1000/1077 - Train Accuracy:  0.902, Validation Accuracy:  0.901, Loss:  0.066
# Epoch  13 Batch    0/1077 - Train Accuracy:  0.894, Validation Accuracy:  0.887, Loss:  0.067
# Epoch  13 Batch  100/1077 - Train Accuracy:  0.899, Validation Accuracy:  0.884, Loss:  0.065
# Epoch  13 Batch  200/1077 - Train Accuracy:  0.871, Validation Accuracy:  0.909, Loss:  0.069
# Epoch  13 Batch  300/1077 - Train Accuracy:  0.911, Validation Accuracy:  0.897, Loss:  0.057
# Epoch  13 Batch  400/1077 - Train Accuracy:  0.895, Validation Accuracy:  0.896, Loss:  0.070
# Epoch  13 Batch  500/1077 - Train Accuracy:  0.921, Validation Accuracy:  0.906, Loss:  0.061
# Epoch  13 Batch  600/1077 - Train Accuracy:  0.898, Validation Accuracy:  0.880, Loss:  0.068
# Epoch  13 Batch  700/1077 - Train Accuracy:  0.901, Validation Accuracy:  0.886, Loss:  0.056
# Epoch  13 Batch  800/1077 - Train Accuracy:  0.890, Validation Accuracy:  0.901, Loss:  0.068
# Epoch  13 Batch  900/1077 - Train Accuracy:  0.915, Validation Accuracy:  0.891, Loss:  0.059
# Epoch  13 Batch 1000/1077 - Train Accuracy:  0.912, Validation Accuracy:  0.893, Loss:  0.058
# Epoch  14 Batch    0/1077 - Train Accuracy:  0.915, Validation Accuracy:  0.899, Loss:  0.056
# Epoch  14 Batch  100/1077 - Train Accuracy:  0.890, Validation Accuracy:  0.906, Loss:  0.056
# Epoch  14 Batch  200/1077 - Train Accuracy:  0.869, Validation Accuracy:  0.901, Loss:  0.061
# Epoch  14 Batch  300/1077 - Train Accuracy:  0.925, Validation Accuracy:  0.885, Loss:  0.052
# Epoch  14 Batch  400/1077 - Train Accuracy:  0.884, Validation Accuracy:  0.901, Loss:  0.062
# Epoch  14 Batch  500/1077 - Train Accuracy:  0.926, Validation Accuracy:  0.882, Loss:  0.051
# Epoch  14 Batch  600/1077 - Train Accuracy:  0.906, Validation Accuracy:  0.894, Loss:  0.061
# Epoch  14 Batch  700/1077 - Train Accuracy:  0.898, Validation Accuracy:  0.887, Loss:  0.047
# Epoch  14 Batch  800/1077 - Train Accuracy:  0.902, Validation Accuracy:  0.896, Loss:  0.059
# Epoch  14 Batch  900/1077 - Train Accuracy:  0.929, Validation Accuracy:  0.897, Loss:  0.052
# Epoch  14 Batch 1000/1077 - Train Accuracy:  0.914, Validation Accuracy:  0.901, Loss:  0.050
# Epoch  15 Batch    0/1077 - Train Accuracy:  0.910, Validation Accuracy:  0.893, Loss:  0.049
# Epoch  15 Batch  100/1077 - Train Accuracy:  0.905, Validation Accuracy:  0.904, Loss:  0.050
# Epoch  15 Batch  200/1077 - Train Accuracy:  0.889, Validation Accuracy:  0.896, Loss:  0.052
# Epoch  15 Batch  300/1077 - Train Accuracy:  0.940, Validation Accuracy:  0.895, Loss:  0.045
# Epoch  15 Batch  400/1077 - Train Accuracy:  0.894, Validation Accuracy:  0.907, Loss:  0.058
# Epoch  15 Batch  500/1077 - Train Accuracy:  0.925, Validation Accuracy:  0.891, Loss:  0.048
# Epoch  15 Batch  600/1077 - Train Accuracy:  0.905, Validation Accuracy:  0.885, Loss:  0.058
# Epoch  15 Batch  700/1077 - Train Accuracy:  0.911, Validation Accuracy:  0.906, Loss:  0.043
# Epoch  15 Batch  800/1077 - Train Accuracy:  0.903, Validation Accuracy:  0.890, Loss:  0.053
# Epoch  15 Batch  900/1077 - Train Accuracy:  0.926, Validation Accuracy:  0.895, Loss:  0.051
# Epoch  15 Batch 1000/1077 - Train Accuracy:  0.918, Validation Accuracy:  0.915, Loss:  0.047
# Epoch  16 Batch    0/1077 - Train Accuracy:  0.919, Validation Accuracy:  0.902, Loss:  0.046
# Epoch  16 Batch  100/1077 - Train Accuracy:  0.906, Validation Accuracy:  0.903, Loss:  0.049
# Epoch  16 Batch  200/1077 - Train Accuracy:  0.906, Validation Accuracy:  0.895, Loss:  0.049
# Epoch  16 Batch  300/1077 - Train Accuracy:  0.936, Validation Accuracy:  0.900, Loss:  0.041
# Epoch  16 Batch  400/1077 - Train Accuracy:  0.893, Validation Accuracy:  0.895, Loss:  0.054
# Epoch  16 Batch  500/1077 - Train Accuracy:  0.931, Validation Accuracy:  0.896, Loss:  0.045
# Epoch  16 Batch  600/1077 - Train Accuracy:  0.911, Validation Accuracy:  0.899, Loss:  0.054
# Epoch  16 Batch  700/1077 - Train Accuracy:  0.912, Validation Accuracy:  0.908, Loss:  0.038
# Epoch  16 Batch  800/1077 - Train Accuracy:  0.909, Validation Accuracy:  0.910, Loss:  0.042
# Epoch  16 Batch  900/1077 - Train Accuracy:  0.927, Validation Accuracy:  0.909, Loss:  0.047
# Epoch  16 Batch 1000/1077 - Train Accuracy:  0.915, Validation Accuracy:  0.897, Loss:  0.043
# Epoch  17 Batch    0/1077 - Train Accuracy:  0.927, Validation Accuracy:  0.903, Loss:  0.040
# Epoch  17 Batch  100/1077 - Train Accuracy:  0.917, Validation Accuracy:  0.906, Loss:  0.041
# Epoch  17 Batch  200/1077 - Train Accuracy:  0.918, Validation Accuracy:  0.910, Loss:  0.038
# Epoch  17 Batch  300/1077 - Train Accuracy:  0.940, Validation Accuracy:  0.902, Loss:  0.035
# Epoch  17 Batch  400/1077 - Train Accuracy:  0.902, Validation Accuracy:  0.910, Loss:  0.047
# Epoch  17 Batch  500/1077 - Train Accuracy:  0.942, Validation Accuracy:  0.904, Loss:  0.040
# Epoch  17 Batch  600/1077 - Train Accuracy:  0.916, Validation Accuracy:  0.902, Loss:  0.049
# Epoch  17 Batch  700/1077 - Train Accuracy:  0.916, Validation Accuracy:  0.915, Loss:  0.034
# Epoch  17 Batch  800/1077 - Train Accuracy:  0.923, Validation Accuracy:  0.916, Loss:  0.045
# Epoch  17 Batch  900/1077 - Train Accuracy:  0.914, Validation Accuracy:  0.909, Loss:  0.044
# Epoch  17 Batch 1000/1077 - Train Accuracy:  0.925, Validation Accuracy:  0.901, Loss:  0.042
# Epoch  18 Batch    0/1077 - Train Accuracy:  0.936, Validation Accuracy:  0.912, Loss:  0.037
# Epoch  18 Batch  100/1077 - Train Accuracy:  0.900, Validation Accuracy:  0.901, Loss:  0.041
# Epoch  18 Batch  200/1077 - Train Accuracy:  0.918, Validation Accuracy:  0.902, Loss:  0.038
# Epoch  18 Batch  300/1077 - Train Accuracy:  0.954, Validation Accuracy:  0.905, Loss:  0.034
# Epoch  18 Batch  400/1077 - Train Accuracy:  0.914, Validation Accuracy:  0.916, Loss:  0.045
# Epoch  18 Batch  500/1077 - Train Accuracy:  0.939, Validation Accuracy:  0.912, Loss:  0.037
# Epoch  18 Batch  600/1077 - Train Accuracy:  0.913, Validation Accuracy:  0.902, Loss:  0.046
# Epoch  18 Batch  700/1077 - Train Accuracy:  0.933, Validation Accuracy:  0.910, Loss:  0.040
# Epoch  18 Batch  800/1077 - Train Accuracy:  0.914, Validation Accuracy:  0.918, Loss:  0.037
# Epoch  18 Batch  900/1077 - Train Accuracy:  0.938, Validation Accuracy:  0.920, Loss:  0.040
# Epoch  18 Batch 1000/1077 - Train Accuracy:  0.929, Validation Accuracy:  0.914, Loss:  0.038
# Epoch  19 Batch    0/1077 - Train Accuracy:  0.942, Validation Accuracy:  0.911, Loss:  0.035
# Epoch  19 Batch  100/1077 - Train Accuracy:  0.927, Validation Accuracy:  0.913, Loss:  0.038
# Epoch  19 Batch  200/1077 - Train Accuracy:  0.944, Validation Accuracy:  0.932, Loss:  0.035
# Epoch  19 Batch  300/1077 - Train Accuracy:  0.946, Validation Accuracy:  0.913, Loss:  0.033
# Epoch  19 Batch  400/1077 - Train Accuracy:  0.905, Validation Accuracy:  0.917, Loss:  0.042
# Epoch  19 Batch  500/1077 - Train Accuracy:  0.939, Validation Accuracy:  0.921, Loss:  0.031
# Epoch  19 Batch  600/1077 - Train Accuracy:  0.926, Validation Accuracy:  0.909, Loss:  0.041
# Epoch  19 Batch  700/1077 - Train Accuracy:  0.950, Validation Accuracy:  0.934, Loss:  0.028
# Epoch  19 Batch  800/1077 - Train Accuracy:  0.927, Validation Accuracy:  0.928, Loss:  0.034
# Epoch  19 Batch  900/1077 - Train Accuracy:  0.939, Validation Accuracy:  0.928, Loss:  0.040
# Epoch  19 Batch 1000/1077 - Train Accuracy:  0.926, Validation Accuracy:  0.922, Loss:  0.041
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    words = sentence.lower().split(" ")
    return [vocab_to_int[word] if word in vocab_to_int else vocab_to_int['<UNK>'] for word in words]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [186, 178, 224, 135, 52, 67, 5]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [263, 335, 327, 174, 354, 327, 25, 88, 1]
#   French Words: ['elle', 'est', 'le', 'nouvelle', 'aimé', 'le', 'sec', '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
