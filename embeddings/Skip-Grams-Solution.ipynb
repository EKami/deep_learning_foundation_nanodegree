# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6726 0.1327 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5840 0.1301 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5190 0.1305 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6175 0.1304 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5192 0.1302 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5193 0.1302 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5309 0.1304 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5603 0.1303 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4565 0.1301 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4396 0.1302 sec/batch
# Nearest to with: neath, blackwood, insignificance, parastatal, dialling, udp, ircs, lla,
# Nearest to are: legends, pays, decoded, experiencing, prairies, dagestani, homeschooling, lookahead,
# Nearest to zero: greenblatt, catechisms, ochs, communicate, galaxy, rick, sacred, murabitun,
# Nearest to so: haller, nep, grasp, ahl, flippers, crean, decentralisation, rangle,
# Nearest to had: limerick, terror, mccarthyism, encounters, yardage, register, carlsson, campaign,
# Nearest to i: trophies, rainforests, manufacturer, pedagogical, sabbatical, visibility, valo, basing,
# Nearest to been: ebook, delivered, proportioned, granny, nyasaland, compensated, hanlon, morro,
# Nearest to only: premier, purr, nanotube, lorenzo, beiderbecke, dissociates, kertzer, low,
# Nearest to account: poindexter, opcw, chaney, fragments, imparting, freising, copulas, joinville,
# Nearest to mean: doubts, sympathizer, cisleithania, rosso, inspiration, zetalisp, promiscuity, archivist,
# Nearest to bible: attaining, eisenstein, misleadingly, insert, attacked, narrowness, period, orleans,
# Nearest to ice: arouse, conglomerates, detonating, ramirez, rodrigo, kore, roget, spectators,
# Nearest to arts: zahn, plundered, afternoon, inundation, microprocessors, cowdery, dadaists, theognis,
# Nearest to construction: formerly, ashanti, composition, navies, longer, iteratively, tutankhamun, prism,
# Nearest to versions: callet, popolo, bartenders, bobbing, stopover, posthumously, valet, relevance,
# Nearest to square: peanuts, mq, round, create, discontinued, drive, kamehameha, consonance,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4890 0.1305 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4062 0.1298 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3246 0.1293 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2681 0.1312 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2112 0.1298 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1796 0.1295 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1175 0.1294 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0765 0.1297 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0003 0.1294 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9922 0.1295 sec/batch
# Nearest to with: blackwood, dialling, parastatal, thrown, udp, insignificance, king, sound,
# Nearest to are: legends, experiencing, decoded, prairies, pays, dagestani, fibre, prompted,
# Nearest to zero: communicate, com, galaxy, greenblatt, sacred, rick, gradient, one,
# Nearest to so: rate, grasp, fourth, nep, haller, unambiguously, james, throw,
# Nearest to had: terror, register, campaign, mccarthyism, encounters, revolution, yardage, completed,
# Nearest to i: trophies, manufacturer, rainforests, visibility, demographic, pedagogical, sabbatical, basing,
# Nearest to been: foreigners, ebook, delivered, partners, recovered, people, producer, chosen,
# Nearest to only: premier, low, during, nanotube, purr, lorenzo, physics, transform,
# Nearest to account: poindexter, fragments, languages, opcw, sniff, distributed, chaney, peel,
# Nearest to mean: decided, inspiration, promiscuity, doubts, sympathizer, cisleithania, rainfall, sons,
# Nearest to bible: period, attaining, eisenstein, attacked, misleadingly, orleans, results, context,
# Nearest to ice: conglomerates, arouse, rodrigo, detonating, spectators, ramirez, roget, obstructed,
# Nearest to arts: zahn, afternoon, cowdery, existent, constraints, cubs, inundation, microprocessors,
# Nearest to construction: formerly, longer, composition, navies, ashanti, prism, tutankhamun, sepultura,
# Nearest to versions: relevance, northamptonshire, megahertz, stopover, hirelings, wireless, contrasts, dented,
# Nearest to square: peanuts, create, round, mq, drive, incur, discontinued, music,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9387 0.1304 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9098 0.1294 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8718 0.1296 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8674 0.1299 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8141 0.1298 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7972 0.1299 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8032 0.1295 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7899 0.1297 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7747 0.1294 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7914 0.1297 sec/batch
# Nearest to with: insignificance, dialling, blackwood, thrown, udp, parastatal, fleet, neath,
# Nearest to are: legends, experiencing, pays, prairies, decoded, manipulate, frame, dagestani,
# Nearest to zero: com, greenblatt, one, communicate, galaxy, norbert, rick, java,
# Nearest to so: grasp, unambiguously, haller, nep, throw, decentralisation, rogue, monetary,
# Nearest to had: terror, encounters, mccarthyism, campaign, register, limerick, revolution, yardage,
# Nearest to i: manufacturer, trophies, rainforests, basing, geek, pedagogical, sabbatical, usurped,
# Nearest to been: ebook, delivered, compensated, solutions, hide, panama, partners, silent,
# Nearest to only: premier, low, during, nanotube, lorenzo, purr, egyptians, physics,
# Nearest to account: poindexter, fragments, distributed, imparting, chaney, joinville, sniff, underdeveloped,
# Nearest to mean: doubts, decided, sympathizer, inspiration, promiscuity, rainfall, friedrich, cisleithania,
# Nearest to bible: attaining, eisenstein, attacked, period, orleans, insert, oriental, misleadingly,
# Nearest to ice: conglomerates, arouse, spectators, rodrigo, urban, ramirez, alignments, imagine,
# Nearest to arts: zahn, afternoon, microprocessors, forts, existent, cubs, plundered, cowdery,
# Nearest to construction: formerly, longer, composition, ashanti, tutankhamun, navies, prism, iteratively,
# Nearest to versions: relevance, motif, northamptonshire, occurrence, stopover, megahertz, dented, posthumously,
# Nearest to square: peanuts, create, round, mq, discontinued, drive, incur, music,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7698 0.1302 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7456 0.1294 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7405 0.1290 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7352 0.1296 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7295 0.1294 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7077 0.1297 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7293 0.1292 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7320 0.1294 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7038 0.1295 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6464 0.1294 sec/batch
# Nearest to with: udp, dialling, insignificance, blackwood, parastatal, thrown, neath, beneficiaries,
# Nearest to are: legends, decoded, experiencing, prairies, pays, dagestani, frame, worthless,
# Nearest to zero: one, com, greenblatt, est, norbert, java, testifying, galaxy,
# Nearest to so: grasp, nep, unambiguously, grapefruit, rogue, haller, should, flippers,
# Nearest to had: terror, limerick, encounters, mccarthyism, campaign, revolution, yardage, reaffirming,
# Nearest to i: rainforests, manufacturer, basing, bows, trophies, usurped, geek, valo,
# Nearest to been: ebook, nyasaland, delivered, compensated, panama, cannabis, resist, foreigners,
# Nearest to only: low, premier, egyptians, lorenzo, nanotube, purr, docteur, mdp,
# Nearest to account: poindexter, fragments, underdeveloped, imparting, joinville, distributed, quintessential, peel,
# Nearest to mean: doubts, rainfall, sympathizer, decided, promiscuity, rosso, friedrich, cisleithania,
# Nearest to bible: attaining, oriental, eisenstein, misleadingly, period, insert, kurukshetra, hansard,
# Nearest to ice: arouse, conglomerates, ramirez, urban, alignments, spectators, aros, rodrigo,
# Nearest to arts: zahn, microprocessors, afternoon, plundered, cowdery, corey, cubs, inundation,
# Nearest to construction: formerly, ashanti, tutankhamun, composition, prism, longer, kosher, dynasties,
# Nearest to versions: relevance, motif, northamptonshire, kaliningrad, hirelings, callet, stopover, megahertz,
# Nearest to square: peanuts, create, round, mq, discontinued, drive, incur, directive,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6589 0.1296 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6722 0.1295 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6127 0.1293 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6356 0.1298 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6615 0.1292 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6211 0.1294 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6032 0.0974 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5577 0.1293 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5172 0.1295 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5018 0.1297 sec/batch
# Nearest to with: udp, dialling, insignificance, neath, blackwood, beneficiaries, primates, thrown,
# Nearest to are: decoded, experiencing, legends, frame, prairies, dagestani, pays, worthless,
# Nearest to zero: one, com, greenblatt, norbert, est, five, rick, java,
# Nearest to so: grasp, nep, grapefruit, unambiguously, should, haller, crean, rogue,
# Nearest to had: limerick, mccarthyism, terror, campaign, encounters, consolidated, yardage, reaffirming,
# Nearest to i: rainforests, bows, basing, valo, manufacturer, pointless, usurped, syst,
# Nearest to been: nyasaland, delivered, compensated, ebook, denouncing, resist, curator, cannabis,
# Nearest to only: egyptians, say, low, purr, nanotube, clinicians, lorenzo, exams,
# Nearest to account: poindexter, fragments, underdeveloped, joinville, imparting, quintessential, sniff, freising,
# Nearest to mean: rainfall, doubts, necessarily, rosso, promiscuity, finite, momenta, rajons,
# Nearest to bible: attaining, oriental, kurukshetra, misleadingly, eisenstein, veneration, period, narrowness,
# Nearest to ice: arouse, conglomerates, ramirez, alloys, roget, spectators, obstructed, aros,
# Nearest to arts: zahn, inundation, cowdery, plundered, microprocessors, cubs, afternoon, theognis,
# Nearest to construction: formerly, prism, tutankhamun, iteratively, ashanti, physically, longer, dynasties,
# Nearest to versions: relevance, motif, kaliningrad, hirelings, stopover, dented, northamptonshire, occurrence,
# Nearest to square: peanuts, create, incur, round, discontinued, drive, mq, unit,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5051 0.1299 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5020 0.1298 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4694 0.1293 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4934 0.1295 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5182 0.1294 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4962 0.1294 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4523 0.1291 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3918 0.1293 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4498 0.1290 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4206 0.1289 sec/batch
# Nearest to with: udp, dialling, neath, insignificance, blackwood, thrown, refinement, beneficiaries,
# Nearest to are: decoded, experiencing, prairies, separated, dagestani, frame, worthless, biochemical,
# Nearest to zero: one, est, com, million, three, five, two, total,
# Nearest to so: grasp, grapefruit, nep, rogue, should, haller, crean, decentralisation,
# Nearest to had: limerick, campaign, encounters, mccarthyism, consolidated, terror, reaffirming, revolution,
# Nearest to i: rainforests, bows, valo, pointless, basing, yezhov, manufacturer, usurped,
# Nearest to been: nyasaland, denouncing, compensated, delivered, resist, patiently, lumi, righteous,
# Nearest to only: egyptians, nanotube, lorenzo, say, clinicians, low, exams, docteur,
# Nearest to account: poindexter, fragments, joinville, underdeveloped, imparting, sniff, copulas, freising,
# Nearest to mean: rainfall, necessarily, doubts, rosso, promiscuity, finite, momenta, thermal,
# Nearest to bible: attaining, church, oriental, revelation, kurukshetra, says, misleadingly, veneration,
# Nearest to ice: arouse, conglomerates, ramirez, spectators, alignments, roget, obstructed, alloys,
# Nearest to arts: zahn, inundation, afternoon, cowdery, hopf, microprocessors, cubs, theognis,
# Nearest to construction: formerly, iteratively, tutankhamun, prism, dynasties, physically, ashanti, claimant,
# Nearest to versions: motif, relevance, stopover, hirelings, metallic, upgrades, dented, kaliningrad,
# Nearest to square: peanuts, unit, round, discontinued, maritime, incur, located, mq,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4413 0.1300 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4201 0.1289 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4343 0.1289 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4104 0.1291 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4241 0.1288 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4173 0.1294 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3878 0.1291 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3480 0.1292 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4103 0.1290 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3955 0.1291 sec/batch
# Nearest to with: udp, dialling, neath, insignificance, ircs, blackwood, thrown, toolbox,
# Nearest to are: decoded, prairies, experiencing, separated, ratio, legends, pays, millilitre,
# Nearest to zero: one, est, com, two, five, three, million, norbert,
# Nearest to so: grapefruit, grasp, should, nep, crean, tingling, haller, asides,
# Nearest to had: consolidated, limerick, campaign, encounters, terror, mccarthyism, reaffirming, unquestionable,
# Nearest to i: rainforests, bows, basing, yezhov, pointless, valo, if, bradley,
# Nearest to been: nyasaland, denouncing, compensated, delivered, lumi, righteous, resist, nonliving,
# Nearest to only: egyptians, nanotube, say, negative, dissociates, exams, docteur, during,
# Nearest to account: poindexter, fragments, joinville, imparting, underdeveloped, sniff, copulas, lemmings,
# Nearest to mean: necessarily, rainfall, doubts, rosso, finite, tcl, momenta, promiscuity,
# Nearest to bible: oriental, church, attaining, revelation, veneration, kurukshetra, testament, says,
# Nearest to ice: arouse, conglomerates, spectators, ramirez, detonating, roget, alignments, obstructed,
# Nearest to arts: zahn, cubs, alder, cowdery, afternoon, theognis, hopf, waylon,
# Nearest to construction: formerly, tutankhamun, iteratively, prism, liouville, ashanti, dynasties, assassination,
# Nearest to versions: motif, dented, stopover, hirelings, bartenders, kaliningrad, cache, northamptonshire,
# Nearest to square: unit, peanuts, round, maritime, discontinued, incur, supervisory, mq,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3600 0.1299 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3774 0.1294 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3580 0.1293 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3545 0.1293 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4078 0.1289 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3615 0.1290 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4053 0.1292 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3695 0.1292 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3235 0.1288 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3010 0.1289 sec/batch
# Nearest to with: udp, neath, insignificance, dialling, ircs, lla, groups, endemic,
# Nearest to are: prairies, millilitre, decoded, separated, topologically, pays, ratio, legends,
# Nearest to zero: one, five, two, three, est, com, total, four,
# Nearest to so: grapefruit, grasp, should, haller, asides, unambiguously, flippers, tingling,
# Nearest to had: limerick, consolidated, reaffirming, unquestionable, campaign, encounters, mccarthyism, terror,
# Nearest to i: bows, rainforests, yezhov, if, basing, usurped, pointless, valo,
# Nearest to been: nyasaland, denouncing, nonliving, compensated, righteous, resist, foreigners, bloc,
# Nearest to only: dissociates, egyptians, say, exams, nanotube, boss, clinicians, docteur,
# Nearest to account: poindexter, fragments, imparting, joinville, underdeveloped, sniff, caucasoid, justified,
# Nearest to mean: rainfall, doubts, rajons, necessarily, finite, equivalence, elliptic, tcl,
# Nearest to bible: oriental, veneration, revelation, attaining, church, kurukshetra, gospel, testament,
# Nearest to ice: arouse, conglomerates, alloys, hotspot, ramirez, roget, yellow, alignments,
# Nearest to arts: zahn, birmingham, alder, corey, shortlist, cubs, waylon, hopf,
# Nearest to construction: formerly, tutankhamun, prism, iteratively, liouville, ashanti, assassination, dynasties,
# Nearest to versions: motif, dented, stopover, upgrades, bobbing, hirelings, cache, stewart,
# Nearest to square: unit, maritime, peanuts, round, located, discontinued, supervisory, mq,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3454 0.1304 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2895 0.1293 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3758 0.1298 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3799 0.1290 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3780 0.1291 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2944 0.1290 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2981 0.1293 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3240 0.1295 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1863 0.1291 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3003 0.1289 sec/batch
# Nearest to with: udp, neath, dialling, lla, insignificance, endemic, ircs, glam,
# Nearest to are: millilitre, separated, legends, topologically, decoded, solidus, prairies, ratio,
# Nearest to zero: one, five, two, three, est, four, com, births,
# Nearest to so: grapefruit, should, asides, tingling, grasp, unambiguously, fifo, haller,
# Nearest to had: unquestionable, reaffirming, consolidated, limerick, campaign, encounters, terror, mccarthyism,
# Nearest to i: if, bows, yezhov, pointless, rainforests, myself, valo, porgy,
# Nearest to been: nyasaland, denouncing, nonliving, righteous, compensated, lumi, bloc, hydrides,
# Nearest to only: dissociates, nanotube, egyptians, boss, say, negative, exams, purr,
# Nearest to account: poindexter, fragments, joinville, underdeveloped, imparting, pilgrim, caucasoid, sniff,
# Nearest to mean: rainfall, rajons, doubts, momenta, necessarily, equivalence, promiscuity, tcl,
# Nearest to bible: veneration, attaining, revelation, oriental, kurukshetra, church, deuterocanonical, eden,
# Nearest to ice: conglomerates, arouse, hotspot, alloys, ramirez, spectators, topographic, alignments,
# Nearest to arts: zahn, birmingham, topics, universities, shortlist, known, emphasize, repressions,
# Nearest to construction: formerly, iteratively, tutankhamun, liouville, prism, uranium, metro, ashanti,
# Nearest to versions: motif, stopover, virtual, upgrades, dented, cache, mf, hirelings,
# Nearest to square: unit, maritime, located, peanuts, discontinued, round, mq, lies,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3088 0.1303 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2770 0.1292 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3349 0.0648 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2349 0.1293 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2280 0.1292 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2058 0.1293 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2238 0.1297 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2026 0.1291 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2375 0.1291 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1871 0.1289 sec/batch
# Nearest to with: udp, thrown, neath, endemic, dialling, cinder, lla, athelstan,
# Nearest to are: millilitre, prairies, solidus, decoded, topologically, separated, makepeace, breed,
# Nearest to zero: five, one, two, three, four, est, nine, total,
# Nearest to so: grapefruit, tingling, should, asides, haller, grasp, rangle, rogue,
# Nearest to had: unquestionable, reaffirming, campaign, limerick, stratigraphic, encounters, consolidated, terror,
# Nearest to i: if, bows, myself, yezhov, pointless, basing, rainforests, coronado,
# Nearest to been: nyasaland, denouncing, nonliving, lumi, compensated, bloc, hydrides, hypocrites,
# Nearest to only: egyptians, boss, nanotube, exams, purr, dissociates, docteur, kertzer,
# Nearest to account: fragments, poindexter, joinville, pilgrim, caucasoid, sniff, imparting, underdeveloped,
# Nearest to mean: rainfall, rajons, momenta, doubts, necessarily, cisleithania, nabla, promiscuity,
# Nearest to bible: revelation, veneration, deuterocanonical, attaining, oriental, kurukshetra, tiberian, church,
# Nearest to ice: conglomerates, arouse, alloys, spectators, ramirez, topographic, hotspot, strutt,
# Nearest to arts: zahn, birmingham, universities, topics, known, shortlist, repressions, emphasize,
# Nearest to construction: formerly, iteratively, liouville, metro, prism, tutankhamun, located, navies,
# Nearest to versions: motif, upgrades, virtual, ram, instruction, mf, cache, bobbing,
# Nearest to square: unit, located, maritime, kilometres, lies, plateaus, round, mq,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2408 0.1297 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2576 0.1293 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2094 0.1291 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1643 0.1290 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2179 0.1287 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1720 0.1291 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1446 0.1292 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1889 0.1293 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1948 0.1295 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1695 0.1292 sec/batch
# Nearest to with: udp, neath, thrown, endemic, dialling, cinder, lla, glam,
# Nearest to are: millilitre, monophyletic, topologically, mahavira, decoded, prairies, triatoma, separated,
# Nearest to zero: one, five, two, three, four, est, nine, total,
# Nearest to so: should, grapefruit, tingling, shots, rangle, fifo, asides, haller,
# Nearest to had: unquestionable, reaffirming, stratigraphic, consolidated, campaign, limerick, encounters, mccarthyism,
# Nearest to i: if, myself, bows, yezhov, sacramental, child, basing, pointless,
# Nearest to been: denouncing, nyasaland, nonliving, lumi, compensated, hydrides, hypocrites, bloc,
# Nearest to only: boss, egyptians, say, exams, pli, purr, clinicians, kertzer,
# Nearest to account: poindexter, fragments, joinville, pilgrim, sniff, underdeveloped, caucasoid, lemass,
# Nearest to mean: rainfall, rajons, momenta, cisleithania, necessarily, doubts, hochdeutsch, nabla,
# Nearest to bible: deuterocanonical, veneration, revelation, attaining, oriental, kurukshetra, eden, testament,
# Nearest to ice: alloys, topographic, conglomerates, hotspot, spectators, arouse, obstructed, gypsum,
# Nearest to arts: universities, birmingham, zahn, undergraduate, school, shortlist, professor, known,
# Nearest to construction: formerly, iteratively, metro, liouville, tutankhamun, located, prism, ashanti,
# Nearest to versions: motif, upgrades, virtual, bohemians, stopover, instruction, ms, mf,
# Nearest to square: unit, located, kilometres, maritime, lies, round, plateaus, supervisory,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1733 0.1298 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2273 0.1294 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1628 0.1294 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1454 0.1291 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1993 0.1295 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1839 0.1291 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1896 0.1293 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1595 0.1291 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1613 0.1291 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1738 0.1294 sec/batch
# Nearest to with: udp, neath, groups, cinder, dialling, insignificance, thrown, glam,
# Nearest to are: millilitre, mahavira, topologically, monophyletic, prefer, prairies, isoglosses, lorids,
# Nearest to zero: five, one, three, two, four, est, nine, total,
# Nearest to so: should, haller, grapefruit, fifo, rangle, brighter, asides, shots,
# Nearest to had: unquestionable, reaffirming, stratigraphic, limerick, consolidated, campaign, mccarthyism, encounters,
# Nearest to i: if, myself, t, yezhov, bows, basing, solway, fusional,
# Nearest to been: nyasaland, denouncing, nonliving, lumi, compensated, righteous, hydrides, copulas,
# Nearest to only: boss, egyptians, pli, say, exams, kertzer, purr, represented,
# Nearest to account: fragments, poindexter, joinville, essex, underdeveloped, predict, imparting, hyphenated,
# Nearest to mean: rainfall, rajons, doubts, cisleithania, momenta, sons, necessarily, elliptic,
# Nearest to bible: deuterocanonical, attaining, veneration, kurukshetra, oriental, revelation, eden, misleadingly,
# Nearest to ice: hotspot, topographic, alloys, conglomerates, arouse, spectators, strutt, obstructed,
# Nearest to arts: birmingham, universities, zahn, undergraduate, school, doctoral, graduate, known,
# Nearest to construction: formerly, iteratively, liouville, metro, tutankhamun, prism, ashanti, located,
# Nearest to versions: motif, upgrades, bohemians, virtual, foraminifera, stewart, rendered, stopover,
# Nearest to square: unit, located, lies, kilometres, maritime, round, supervisory, toho,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2431 0.1297 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1542 0.1293 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2144 0.1292 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1961 0.1292 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1381 0.1303 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1394 0.1319 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1766 0.1294 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0787 0.1295 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2032 0.1297 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2230 0.1296 sec/batch
# Nearest to with: udp, neath, glam, insignificance, groups, athelstan, claremont, monnet,
# Nearest to are: mahavira, lorids, millilitre, prairies, isoglosses, secularization, prefer, monophyletic,
# Nearest to zero: five, two, one, three, four, nine, est, seven,
# Nearest to so: should, haller, asides, grapefruit, fifo, tingling, crean, rangle,
# Nearest to had: reaffirming, unquestionable, limerick, stratigraphic, consolidated, campaign, encounters, manzikert,
# Nearest to i: if, t, yezhov, solway, myself, fusional, child, sacramental,
# Nearest to been: nyasaland, denouncing, lumi, colonialism, righteous, josaphat, nonliving, compensated,
# Nearest to only: boss, egyptians, pli, kertzer, exams, say, represented, purr,
# Nearest to account: poindexter, fragments, essex, pilgrim, joinville, copulas, godesberg, caucasoid,
# Nearest to mean: rainfall, rajons, elliptic, momenta, nabla, cisleithania, doubts, hochdeutsch,
# Nearest to bible: deuterocanonical, attaining, veneration, eden, revelation, kurukshetra, oriental, misleadingly,
# Nearest to ice: hotspot, strutt, conglomerates, topographic, alloys, wards, arouse, landforms,
# Nearest to arts: birmingham, universities, doctoral, undergraduate, zahn, school, graduate, known,
# Nearest to construction: formerly, iteratively, liouville, metro, ashanti, tutankhamun, deeply, located,
# Nearest to versions: motif, bohemians, upgrades, stewart, foraminifera, virtual, mf, hamdan,
# Nearest to square: unit, located, lies, kilometres, maritime, toho, plateaus, mq,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2213 0.1301 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1154 0.1298 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1431 0.1291 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1514 0.1295 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0179 0.1296 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1740 0.1296 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1443 0.1297 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1431 0.1297 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1714 0.0325 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1027 0.1292 sec/batch
# Nearest to with: udp, groups, cinder, neath, glam, endemic, sound, pods,
# Nearest to are: lorids, mahavira, isoglosses, millilitre, prefer, topologically, monophyletic, prairies,
# Nearest to zero: five, two, one, three, four, nine, six, est,
# Nearest to so: haller, asides, should, shots, grapefruit, rangle, fifo, tingling,
# Nearest to had: reaffirming, unquestionable, stratigraphic, consolidated, limerick, manzikert, campaign, absorbing,
# Nearest to i: if, t, myself, yezhov, karaoke, fusional, child, solway,
# Nearest to been: denouncing, nyasaland, nonliving, geological, copulas, josaphat, lumi, compensated,
# Nearest to only: boss, pli, egyptians, vector, exams, regardless, negative, kertzer,
# Nearest to account: fragments, poindexter, essex, joinville, predict, copulas, transits, godesberg,
# Nearest to mean: rainfall, rajons, momenta, cisleithania, doubts, elliptic, je, offsets,
# Nearest to bible: deuterocanonical, attaining, veneration, eden, misleadingly, kurukshetra, revelation, davidic,
# Nearest to ice: conglomerates, hotspot, wards, alloys, strutt, topographic, landforms, gypsum,
# Nearest to arts: birmingham, universities, doctoral, school, undergraduate, known, graduate, professor,
# Nearest to construction: formerly, iteratively, metro, liouville, located, ashanti, jambalaya, assassination,
# Nearest to versions: motif, upgrades, ms, bohemians, virtual, version, malibu, hirelings,
# Nearest to square: unit, located, kilometres, lies, maritime, plateaus, round, toho,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0998 0.1298 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0730 0.1297 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0944 0.1295 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0375 0.1295 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0941 0.1293 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0420 0.1290 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1057 0.1294 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0944 0.1292 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1297 0.1291 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0135 0.1293 sec/batch
# Nearest to with: udp, groups, neath, cinder, in, its, endemic, athelstan,
# Nearest to are: isoglosses, mahavira, millilitre, prairies, monophyletic, lorids, prefer, breed,
# Nearest to zero: five, two, one, three, four, nine, six, est,
# Nearest to so: haller, should, shots, broke, asides, tingling, grapefruit, crean,
# Nearest to had: unquestionable, consolidated, stratigraphic, reaffirming, limerick, manzikert, absorbing, register,
# Nearest to i: t, if, myself, solway, yezhov, fusional, child, me,
# Nearest to been: nyasaland, denouncing, geological, nonliving, hydrides, josaphat, copulas, lumi,
# Nearest to only: boss, pli, exams, vector, egyptians, regardless, breach, to,
# Nearest to account: fragments, essex, poindexter, godesberg, asians, hyphenated, pilgrim, joinville,
# Nearest to mean: rainfall, rajons, je, momenta, cisleithania, elliptic, doubts, offsets,
# Nearest to bible: deuterocanonical, attaining, hebrew, veneration, eden, books, kurukshetra, misleadingly,
# Nearest to ice: conglomerates, hotspot, strutt, wards, topographic, alloys, landforms, arouse,
# Nearest to arts: universities, birmingham, doctoral, school, undergraduate, professor, graduate, art,
# Nearest to construction: formerly, metro, iteratively, liouville, located, ashanti, assassination, using,
# Nearest to versions: upgrades, motif, bohemians, ms, cartridge, virtual, malibu, mf,
# Nearest to square: unit, located, kilometres, lies, maritime, coosa, plateaus, round,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0366 0.1298 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0317 0.1290 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0353 0.1291 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0726 0.1295 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0740 0.1291 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0785 0.1288 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0851 0.1293 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1433 0.1294 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0572 0.1293 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0868 0.1291 sec/batch
# Nearest to with: udp, groups, cinder, neath, its, enol, in, sown,
# Nearest to are: monophyletic, triatoma, millilitre, prairies, lorids, isoglosses, mahavira, separated,
# Nearest to zero: five, two, three, one, four, six, nine, est,
# Nearest to so: should, haller, shots, asides, but, rangle, grapefruit, crean,
# Nearest to had: unquestionable, consolidated, stratigraphic, manzikert, reaffirming, register, limerick, returned,
# Nearest to i: t, if, myself, me, you, fusional, child, karaoke,
# Nearest to been: nyasaland, denouncing, geological, hydrides, lumi, colonialism, nonliving, shalt,
# Nearest to only: boss, pli, egyptians, vector, say, breach, exams, to,
# Nearest to account: fragments, essex, hyphenated, coincident, poindexter, godesberg, copulas, pilgrim,
# Nearest to mean: rainfall, rajons, je, doubts, offsets, cisleithania, polskiej, momenta,
# Nearest to bible: deuterocanonical, eden, attaining, davidic, misleadingly, kurukshetra, veneration, hebrew,
# Nearest to ice: strutt, alloys, wards, hotspot, topographic, conglomerates, landforms, swimming,
# Nearest to arts: birmingham, doctoral, universities, school, art, undergraduate, graduate, professor,
# Nearest to construction: iteratively, formerly, using, liouville, metro, jambalaya, located, amtrak,
# Nearest to versions: motif, upgrades, bohemians, cartridge, ms, rendered, malibu, analects,
# Nearest to square: unit, located, lies, kilometres, coosa, terminating, plateaus, maritime,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0718 0.1302 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0761 0.1294 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1011 0.1296 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0824 0.1293 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0405 0.1294 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0609 0.1295 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0549 0.1297 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0475 0.1296 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0779 0.1294 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0766 0.1290 sec/batch
# Nearest to with: groups, neath, udp, cinder, its, sown, in, leadership,
# Nearest to are: secularization, mahavira, lorids, monophyletic, triatoma, prefer, eh, collapses,
# Nearest to zero: five, two, three, one, four, six, nine, eight,
# Nearest to so: haller, should, asides, fifo, shots, rogue, crean, occasionaly,
# Nearest to had: unquestionable, consolidated, stratigraphic, manzikert, reaffirming, limerick, princes, abeokuta,
# Nearest to i: t, myself, me, child, fusional, you, ll, if,
# Nearest to been: nyasaland, denouncing, geological, colonialism, hydrides, nonliving, hewson, josaphat,
# Nearest to only: boss, pli, vector, exams, breach, kertzer, introduced, egyptians,
# Nearest to account: fragments, essex, copulas, hyphenated, sip, coincident, wills, poindexter,
# Nearest to mean: rainfall, rajons, je, offsets, cisleithania, momenta, doubts, polskiej,
# Nearest to bible: deuterocanonical, eden, misleadingly, kurukshetra, davidic, attaining, tiberian, practices,
# Nearest to ice: alloys, strutt, wards, conglomerates, landforms, topographic, arouse, hotspot,
# Nearest to arts: birmingham, doctoral, school, universities, art, undergraduate, graduate, professor,
# Nearest to construction: formerly, iteratively, metro, using, liouville, deeply, jambalaya, located,
# Nearest to versions: motif, upgrades, cartridge, bohemians, rendered, ms, malibu, analects,
# Nearest to square: unit, located, lies, kilometres, coosa, toho, terminating, round,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0617 0.1300 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9909 0.1292 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0467 0.1292 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0473 0.1293 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0609 0.1297 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1299 0.1292 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1099 0.1292 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0452 0.1292 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0407 0.1292 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0669 0.1292 sec/batch
# Nearest to with: groups, udp, neath, glam, cinder, its, sown, menace,
# Nearest to are: lorids, isoglosses, prefer, triatoma, millilitre, monophyletic, prairies, secularization,
# Nearest to zero: five, two, three, one, four, six, nine, million,
# Nearest to so: should, asides, haller, but, fifo, shots, rangle, rogue,
# Nearest to had: consolidated, unquestionable, manzikert, reaffirming, stratigraphic, limerick, absorbing, abeokuta,
# Nearest to i: t, myself, me, you, if, karaoke, ll, fusional,
# Nearest to been: nyasaland, geological, denouncing, polg, dwelling, hydrides, righteous, ccp,
# Nearest to only: pli, boss, egyptians, exams, breach, vector, kertzer, clinicians,
# Nearest to account: essex, fragments, godesberg, pilgrim, poindexter, coincident, copulas, wills,
# Nearest to mean: rainfall, rajons, je, offsets, cisleithania, doubts, momenta, polskiej,
# Nearest to bible: deuterocanonical, eden, kurukshetra, davidic, misleadingly, attaining, bunyan, tiberian,
# Nearest to ice: wards, strutt, conglomerates, alloys, landforms, swimming, arouse, topographic,
# Nearest to arts: birmingham, doctoral, universities, school, art, graduate, undergraduate, tei,
# Nearest to construction: iteratively, formerly, metro, deeply, liouville, jambalaya, using, ashanti,
# Nearest to versions: motif, upgrades, bohemians, cartridge, rendered, analects, mf, malibu,
# Nearest to square: unit, located, lies, coosa, kilometres, toho, round, terminating,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9607 0.1302 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0141 0.1294 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0338 0.1290 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0498 0.1292 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0590 0.1294 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0175 0.1293 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0009 0.1296 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9813 0.1295 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0231 0.1300 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9777 0.1298 sec/batch
# Nearest to with: groups, neath, udp, cinder, sown, its, in, glam,
# Nearest to are: monophyletic, isoglosses, makepeace, lorids, secularization, triatoma, prefer, collapses,
# Nearest to zero: five, two, three, one, four, nine, six, eight,
# Nearest to so: haller, asides, should, shots, broke, but, rogue, rangle,
# Nearest to had: unquestionable, manzikert, consolidated, stratigraphic, reaffirming, rushed, journeyed, limerick,
# Nearest to i: t, myself, me, margrave, you, if, solway, ll,
# Nearest to been: nyasaland, dwelling, geological, denouncing, nonliving, righteous, shalt, recantation,
# Nearest to only: boss, pli, egyptians, to, introduced, xxxii, breach, bayeux,
# Nearest to account: essex, fragments, godesberg, wills, pilgrim, modernes, caucasoid, copulas,
# Nearest to mean: rainfall, rajons, je, doubts, offsets, motilal, cisleithania, polskiej,
# Nearest to bible: deuterocanonical, davidic, eden, tiberian, kurukshetra, misleadingly, attaining, tanakh,
# Nearest to ice: conglomerates, strutt, wards, landforms, alloys, swimming, arouse, precipitates,
# Nearest to arts: doctoral, birmingham, school, art, universities, emphasize, undergraduate, tei,
# Nearest to construction: iteratively, metro, formerly, jambalaya, deeply, panavia, using, liouville,
# Nearest to versions: upgrades, motif, bohemians, cartridge, rendered, malibu, emporis, mf,
# Nearest to square: unit, located, coosa, kilometres, lies, toho, plateaus, round,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9948 0.1305 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9334 0.1297 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0078 0.1292 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0076 0.1294 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0321 0.1292 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9770 0.1291 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9280 0.1291 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9604 0.1290 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9299 0.1291 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9936 0.1294 sec/batch
# Nearest to with: groups, udp, cinder, and, in, its, to, neath,
# Nearest to are: monophyletic, collapses, makepeace, triatoma, isoglosses, prefer, prairies, grouped,
# Nearest to zero: five, two, three, one, four, six, nine, eight,
# Nearest to so: shots, haller, asides, should, broke, fifo, crean, humphrey,
# Nearest to had: manzikert, unquestionable, stratigraphic, consolidated, reaffirming, journeyed, mhz, abeokuta,
# Nearest to i: t, myself, me, you, karaoke, margrave, if, ll,
# Nearest to been: nyasaland, dwelling, denouncing, geological, shalt, nonliving, recantation, lumi,
# Nearest to only: to, boss, pli, exams, egyptians, xxxii, breach, introduced,
# Nearest to account: essex, fragments, godesberg, wills, pilgrim, hyphenated, copulas, modernes,
# Nearest to mean: rainfall, rajons, je, offsets, doubts, cisleithania, motilal, momenta,
# Nearest to bible: deuterocanonical, tiberian, davidic, tanakh, hebrew, misleadingly, kurukshetra, habakkuk,
# Nearest to ice: strutt, conglomerates, alloys, wards, landforms, swimming, precipitates, confusingly,
# Nearest to arts: school, doctoral, birmingham, art, universities, undergraduate, graduate, emphasize,
# Nearest to construction: iteratively, deeply, using, jambalaya, metro, formerly, liouville, panavia,
# Nearest to versions: upgrades, bohemians, motif, rendered, cartridge, malibu, reborn, analects,
# Nearest to square: unit, kilometres, located, lies, coosa, toho, terminating, plateaus,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0056 0.1298 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9983 0.1289 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9674 0.1290 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0376 0.1289 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0261 0.1290 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9812 0.1288 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0096 0.1293 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9942 0.1294 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0073 0.1291 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0185 0.1290 sec/batch
# Nearest to with: groups, and, in, udp, its, cinder, neath, a,
# Nearest to are: collapses, makepeace, secularization, monophyletic, lorids, prefer, mahavira, bookmakers,
# Nearest to zero: five, two, three, one, four, nine, six, eight,
# Nearest to so: should, haller, asides, shots, occasionaly, but, fifo, reactions,
# Nearest to had: unquestionable, manzikert, stratigraphic, reaffirming, consolidated, eagerly, abeokuta, journeyed,
# Nearest to i: t, myself, me, you, karaoke, if, ll, margrave,
# Nearest to been: nyasaland, shalt, denouncing, geological, rebuke, recantation, righteous, nonliving,
# Nearest to only: to, introduced, pli, boss, breach, egyptians, xxxii, vector,
# Nearest to account: essex, fragments, godesberg, antoinette, coincident, wills, hyphenated, pilgrim,
# Nearest to mean: rainfall, rajons, je, doubts, motilal, offsets, cisleithania, polskiej,
# Nearest to bible: deuterocanonical, davidic, misleadingly, eden, kurukshetra, hebrew, habakkuk, tiberian,
# Nearest to ice: strutt, conglomerates, wards, alloys, landforms, swimming, arouse, confusingly,
# Nearest to arts: birmingham, doctoral, school, art, universities, graduate, undergraduate, emphasize,
# Nearest to construction: iteratively, using, deeply, jambalaya, metro, formerly, liouville, petrochemical,
# Nearest to versions: motif, rendered, bohemians, upgrades, cartridge, reborn, analects, malibu,
# Nearest to square: unit, terminating, coosa, lies, kilometres, located, toho, round,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0015 0.1301 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9728 0.1295 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9641 0.1292 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9935 0.1291 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0584 0.1291 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0068 0.1294 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9601 0.1293 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9503 0.1294 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9513 0.1291 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0044 0.1291 sec/batch
# Nearest to with: groups, in, its, udp, and, cinder, neath, leadership,
# Nearest to are: secularization, collapses, makepeace, monophyletic, isoglosses, lorids, eh, prefer,
# Nearest to zero: five, two, three, one, four, six, nine, eight,
# Nearest to so: haller, should, asides, shots, broke, but, fractions, crean,
# Nearest to had: stratigraphic, manzikert, consolidated, unquestionable, reaffirming, limerick, absorbing, journeyed,
# Nearest to i: t, myself, me, you, ll, margrave, karaoke, invalidating,
# Nearest to been: nyasaland, geological, denouncing, has, rebuke, recantation, was, shalt,
# Nearest to only: pli, egyptians, breach, introduced, boss, to, vector, xxxii,
# Nearest to account: essex, fragments, godesberg, antoinette, wills, pilgrim, gtp, hyphenated,
# Nearest to mean: rainfall, rajons, offsets, je, motilal, doubts, cisleithania, momenta,
# Nearest to bible: deuterocanonical, misleadingly, davidic, eden, habakkuk, tiberian, kurukshetra, hebrew,
# ...
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8362 0.1288 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7779 0.1290 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8338 0.1293 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8655 0.1297 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8550 0.1293 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8468 0.1290 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8667 0.1290 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9114 0.1290 sec/batch
# Nearest to with: a, the, and, in, to, as, its, an,
# Nearest to are: have, there, a, as, is, makepeace, or, be,
# Nearest to zero: five, three, two, one, four, six, eight, nine,
# Nearest to so: but, should, not, unable, managed, asides, broke, vanishes,
# Nearest to had: were, did, after, later, initially, in, he, now,
# Nearest to i: t, myself, me, you, gracious, my, fuck, sum,
# Nearest to been: has, dwelling, suggested, evidence, have, suggest, remains, widely,
# Nearest to only: to, distinction, with, in, not, introduced, which, was,
# Nearest to account: caucasoid, gtp, refracted, robust, takers, essex, newsgroups, wills,
# Nearest to mean: rainfall, rajons, motilal, je, subpage, munchkin, offsets, doubts,
# Nearest to bible: deuterocanonical, update, bibles, misleadingly, davidic, inconceivable, section, helvetii,
# Nearest to ice: strutt, rink, styrofoam, freeze, decry, glaciation, patent, wards,
# Nearest to arts: art, emphasize, swordsmanship, kansai, grappling, doctoral, martial, birmingham,
# Nearest to construction: using, iteratively, petrochemical, skyscraper, metro, uranium, deeply, jambalaya,
# Nearest to versions: version, ord, qnx, motif, mf, upgrades, reborn, tatian,
# Nearest to square: unit, terminating, coosa, kilometres, toho, mq, num, located,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8224 0.1297 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8584 0.1290 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8463 0.1292 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8389 0.1292 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8584 0.1293 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8807 0.1297 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8660 0.1290 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8150 0.1291 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8519 0.1291 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9032 0.1294 sec/batch
# Nearest to with: the, a, in, and, its, to, as, groups,
# Nearest to are: have, there, makepeace, as, many, is, a, be,
# Nearest to zero: five, two, three, one, four, six, eight, nine,
# Nearest to so: but, should, not, managed, unable, broke, haller, asides,
# Nearest to had: were, did, later, after, which, initially, now, was,
# Nearest to i: t, myself, me, gracious, you, my, fuck, margrave,
# Nearest to been: has, have, suggested, dwelling, evidence, suggest, was, widely,
# Nearest to only: to, distinction, introduced, with, eigenvector, not, ceased, egyptians,
# Nearest to account: refracted, gtp, caucasoid, robust, essex, wills, newsgroups, anthropogenic,
# Nearest to mean: rajons, rainfall, motilal, je, subpage, munchkin, offsets, babbling,
# Nearest to bible: deuterocanonical, bibles, update, misleadingly, inconceivable, section, davidic, kurukshetra,
# Nearest to ice: strutt, rink, freeze, glaciation, decry, styrofoam, productivity, landforms,
# Nearest to arts: art, emphasize, swordsmanship, grappling, kansai, doctoral, martial, fencing,
# Nearest to construction: using, iteratively, metro, skyscraper, petrochemical, uranium, chimneys, jambalaya,
# Nearest to versions: version, qnx, ord, enumerative, warnings, upgrades, mf, tatian,
# Nearest to square: unit, coosa, terminating, toho, mq, kilometres, lya, located,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8681 0.1303 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8630 0.1296 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8493 0.1296 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8381 0.1294 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9154 0.1294 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8231 0.1291 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9592 0.1292 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8996 0.1294 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8974 0.1296 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7983 0.1291 sec/batch
# Nearest to with: a, the, in, and, to, its, groups, as,
# Nearest to are: have, there, many, is, as, a, or, makepeace,
# Nearest to zero: five, two, three, one, four, six, nine, eight,
# Nearest to so: but, should, unable, broke, managed, haller, not, asides,
# Nearest to had: did, were, after, later, initially, he, that, which,
# Nearest to i: t, me, myself, you, my, fuck, margrave, gracious,
# Nearest to been: has, suggested, have, dwelling, evidence, in, was, suggest,
# Nearest to only: to, ceased, distinction, limits, introduced, egyptians, urea, with,
# Nearest to account: gtp, caucasoid, essex, refracted, godesberg, wills, interrogating, page,
# Nearest to mean: rajons, motilal, rainfall, je, munchkin, subpage, offsets, babbling,
# Nearest to bible: bibles, deuterocanonical, misleadingly, update, inconceivable, davidic, section, helvetii,
# Nearest to ice: rink, strutt, freeze, glaciation, styrofoam, decry, landforms, patent,
# Nearest to arts: art, swordsmanship, grappling, emphasize, martial, kansai, fencing, doctoral,
# Nearest to construction: skyscraper, iteratively, metro, using, uranium, petrochemical, meantone, jambalaya,
# Nearest to versions: version, qnx, ord, mf, motif, bohemians, warnings, upgrades,
# Nearest to square: unit, coosa, toho, mq, terminating, kilometres, lya, num,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8141 0.1298 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8217 0.1290 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8022 0.1290 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9078 0.1296 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8323 0.1293 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8650 0.1290 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8328 0.0970 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8352 0.1296 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7959 0.1293 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.9011 0.1295 sec/batch
# Nearest to with: the, a, in, to, and, as, its, an,
# Nearest to are: have, there, is, as, a, many, or, most,
# Nearest to zero: two, five, three, one, four, six, eight, nine,
# Nearest to so: but, unable, should, broke, not, managed, haller, hamburgers,
# Nearest to had: were, was, after, he, did, later, initially, would,
# Nearest to i: t, myself, me, margrave, fuck, you, gracious, my,
# Nearest to been: has, have, suggested, dwelling, evidence, suggest, in, was,
# Nearest to only: to, egyptians, was, ceased, with, distinction, limits, introduced,
# Nearest to account: caucasoid, gtp, refracted, godesberg, essex, wills, interrogating, cardano,
# Nearest to mean: rajons, rainfall, motilal, je, subpage, munchkin, offsets, krug,
# Nearest to bible: bibles, update, deuterocanonical, misleadingly, inconceivable, section, davidic, kurukshetra,
# Nearest to ice: rink, strutt, freeze, styrofoam, glaciation, landforms, decry, patent,
# Nearest to arts: art, grappling, swordsmanship, martial, emphasize, kansai, taekwondo, gendai,
# Nearest to construction: skyscraper, metro, using, jambalaya, petrochemical, iteratively, muskegon, chimneys,
# Nearest to versions: version, qnx, ord, upgrades, reborn, mf, bohemians, motif,
# Nearest to square: unit, coosa, kilometres, mq, toho, terminating, lya, num,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7904 0.1298 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8101 0.1290 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7616 0.1292 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8825 0.1296 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8217 0.1294 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8399 0.1290 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8530 0.1288 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7180 0.1294 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8219 0.1292 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7839 0.1295 sec/batch
# Nearest to with: a, the, in, to, and, its, as, groups,
# Nearest to are: there, have, a, is, as, or, to, in,
# Nearest to zero: five, two, three, one, four, six, eight, nine,
# Nearest to so: unable, but, should, not, shots, managed, broke, haller,
# Nearest to had: were, did, later, after, he, initially, would, was,
# Nearest to i: t, me, myself, you, sum, margrave, fuck, my,
# Nearest to been: has, have, suggested, dwelling, evidence, suggest, in, widely,
# Nearest to only: to, with, in, distinction, was, which, introduced, egyptians,
# Nearest to account: caucasoid, gtp, refracted, page, anthropogenic, godesberg, robust, newsgroups,
# Nearest to mean: rajons, motilal, rainfall, je, subpage, munchkin, offsets, krug,
# Nearest to bible: deuterocanonical, bibles, update, inconceivable, misleadingly, hansard, kurukshetra, section,
# Nearest to ice: rink, freeze, styrofoam, glaciation, strutt, decry, landforms, patent,
# Nearest to arts: art, grappling, swordsmanship, emphasize, martial, kansai, taekwondo, doctoral,
# Nearest to construction: skyscraper, using, metro, tunnels, petrochemical, meantone, jambalaya, iteratively,
# Nearest to versions: version, upgrades, ord, qnx, mf, reborn, altogether, bohemians,
# Nearest to square: unit, kilometres, coosa, mq, terminating, toho, lya, num,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7819 0.1301 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8333 0.1295 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8773 0.1295 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8335 0.1298 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8503 0.1294 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9006 0.1299 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8186 0.1292 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8386 0.1296 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8403 0.1294 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8313 0.1293 sec/batch
# Nearest to with: a, in, the, and, as, its, to, groups,
# Nearest to are: have, there, or, many, a, makepeace, as, of,
# Nearest to zero: five, two, three, one, four, six, eight, nine,
# Nearest to so: but, unable, should, not, shots, haller, hamburgers, managed,
# Nearest to had: were, did, later, after, initially, he, was, suggested,
# Nearest to i: t, me, myself, my, you, margrave, sum, fuck,
# Nearest to been: have, has, suggested, evidence, dwelling, suggest, was, widely,
# Nearest to only: to, in, distinction, with, was, which, xe, not,
# Nearest to account: caucasoid, gtp, refracted, newsgroups, page, opcw, anthropogenic, measuring,
# Nearest to mean: rajons, motilal, rainfall, je, subpage, munchkin, misguided, offsets,
# Nearest to bible: bibles, deuterocanonical, update, hansard, inconceivable, misleadingly, practices, kurukshetra,
# Nearest to ice: rink, freeze, styrofoam, strutt, glaciation, patent, landforms, decry,
# Nearest to arts: art, emphasize, swordsmanship, grappling, martial, kansai, tei, doctoral,
# Nearest to construction: using, skyscraper, chimneys, jambalaya, metro, iteratively, meantone, petrochemical,
# Nearest to versions: version, upgrades, qnx, ord, mf, tatian, motif, reborn,
# Nearest to square: unit, lya, coosa, kilometres, mq, toho, terminating, num,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8541 0.1303 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8698 0.1298 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8288 0.1297 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8287 0.1296 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8462 0.1298 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8430 0.1294 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8419 0.1295 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8357 0.1297 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7834 0.1292 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8333 0.1293 sec/batch
# Nearest to with: the, a, in, and, as, its, to, groups,
# Nearest to are: have, many, there, as, a, or, is, and,
# Nearest to zero: five, two, three, one, four, six, eight, nine,
# Nearest to so: but, not, should, unable, managed, hamburgers, quite, shots,
# Nearest to had: were, did, later, initially, after, he, now, they,
# Nearest to i: t, me, myself, you, my, sum, margrave, ll,
# Nearest to been: has, have, suggested, in, for, was, evidence, suggest,
# Nearest to only: to, in, distinction, with, not, which, was, still,
# Nearest to account: caucasoid, gtp, refracted, newsgroups, page, anthropogenic, measuring, wills,
# Nearest to mean: rajons, rainfall, motilal, subpage, je, munchkin, offsets, krug,
# Nearest to bible: bibles, deuterocanonical, inconceivable, update, misleadingly, revelation, practices, section,
# Nearest to ice: rink, freeze, styrofoam, strutt, glaciation, landforms, decry, csv,
# Nearest to arts: art, emphasize, swordsmanship, grappling, kansai, tei, doctoral, fencing,
# Nearest to construction: skyscraper, metro, using, jambalaya, iteratively, chimneys, tunnels, inlaid,
# Nearest to versions: version, qnx, upgrades, ord, mf, tatian, motif, occurrence,
# Nearest to square: unit, coosa, kilometres, mq, lya, toho, terminating, num,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8768 0.1300 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7935 0.1292 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9395 0.1297 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8892 0.1297 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8908 0.1292 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8177 0.1294 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7897 0.1298 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8569 0.1296 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7516 0.1293 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8452 0.1296 sec/batch
# Nearest to with: a, the, in, to, and, its, as, s,
# Nearest to are: have, there, many, or, a, is, most, more,
# Nearest to zero: five, two, three, one, four, six, eight, seven,
# Nearest to so: but, not, unable, should, on, shots, hamburgers, asides,
# Nearest to had: were, did, later, initially, after, he, joined, soon,
# Nearest to i: t, me, myself, you, my, fuck, gracious, margrave,
# Nearest to been: has, have, suggested, evidence, dwelling, suggest, widely, in,
# Nearest to only: to, distinction, in, was, limits, with, xe, which,
# Nearest to account: caucasoid, gtp, refracted, newsgroups, page, godesberg, wills, pilgrim,
# Nearest to mean: motilal, rajons, rainfall, je, subpage, munchkin, harmonic, krug,
# Nearest to bible: bibles, deuterocanonical, update, inconceivable, misleadingly, section, hansard, rembrandt,
# Nearest to ice: rink, freeze, strutt, styrofoam, glaciation, landforms, csv, decry,
# Nearest to arts: art, swordsmanship, grappling, emphasize, martial, taekwondo, gendai, fencing,
# Nearest to construction: skyscraper, metro, iteratively, using, petrochemical, jambalaya, tunnels, chimneys,
# Nearest to versions: version, qnx, upgrades, mf, ord, motif, warnings, occurrence,
# Nearest to square: unit, coosa, mq, lya, kilometres, toho, terminating, num,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8283 0.1302 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8418 0.1295 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
